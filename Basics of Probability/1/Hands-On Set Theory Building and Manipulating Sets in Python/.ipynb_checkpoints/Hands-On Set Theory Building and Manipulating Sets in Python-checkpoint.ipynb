# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# آزمایشگاه آماری: نظریه مجموعه‌ها و کاربردهای آن در علوم داده
# </font>
# </h1>
#
# <div dir="rtl">
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# نظریه مجموعه‌ها، به عنوان یکی از بنیادهای ریاضیات، نقش محوری در بسیاری از زمینه‌های علمی و فناوری ایفا می‌کند. این شاخه از ریاضیات به ما ابزارهایی برای مدیریت، تحلیل و عملیات روی داده‌های مختلف ارائه می‌دهد. در علوم داده، آمار و احتمال، نظریه مجموعه‌ها به صورت مستقیم در مدل‌سازی پدیده‌ها، تحلیل داده‌ها و طراحی الگوریتم‌ها استفاده می‌شود.
# </div>
# </font>
# </p>
#
# <div dir="rtl">
#     <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
#         <font face="vazir" color="#0099cc">
#             هدف از تمرین:
#         </font>
#     </h3>
#     <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#         <font face="vazir" size=3>
#             هدف اصلی این تمرین، آشنایی شما با مفاهیم اساسی نظریه مجموعه‌ها و نحوه پیاده‌سازی آن‌ها در محیط برنامه‌نویسی پایتون است. در این تمرین، شما با عملیات پایه‌ای مانند اجتماع، اشتراک، تفاضل، متمم و مجموعه توانی آشنا خواهید شد و به حل مسائلی که نیازمند استفاده از این مفاهیم هستند، خواهید پرداخت.<br>
#             پایتون به دلیل سادگی و قدرتمند بودن، یکی از بهترین ابزارهای برنامه‌نویسی برای یادگیری و کاربرد مفاهیم ریاضی است. در این زبان، ساختار داده‌ای <code>set</code> به ما اجازه می‌دهد تا به راحتی عملیات مجموعه‌ای را پیاده‌سازی کنیم. این تمرین، علاوه بر یادگیری مفاهیم نظریه مجموعه‌ها، تجربه کدنویسی شما را نیز بهبود می‌بخشد.
#         </font>
#     </p>
# </div>
#
# <div dir="rtl">
#     <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
#         <font face="vazir" color="#0099cc">
#             ساختار تمرین:
#         </font>
#     </h3>
#     <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#         <font face="vazir" size=3>
#             این تمرین شامل دو بخش است:
#             <ol>
#                 <li><strong>بخش نظری:</strong> در این بخش، مفاهیم اصلی نظریه مجموعه‌ها مانند اجتماع، اشتراک، تفاضل، متمم و مجموعه توانی مرور می‌شوند.</li>
#                 <li><strong>بخش عملی:</strong> در این بخش، شما می‌بایست مفاهیم یادگرفته را در محیط پایتون پیاده‌سازی کنید. برخی از سوالات شامل طراحی توابع برای انجام عملیات مجموعه‌ای و حل مسائل واقعی هستند.</li>
#             </ol>
#         </font>
#     </p>
# </div>
#
# <div dir="rtl">
#     <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
#         <font face="vazir" color="#0099cc">
#             چه چیزی از این تمرین یاد می‌گیرید؟
#         </font>
#     </h3>
#     <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#         <font face="vazir" size=3>
#             <ul>
#                 <li><strong>مفاهیم اساسی نظریه مجموعه‌ها:</strong> اجتماع، اشتراک، تفاضل، متمم و مجموعه توانی.</li>
#                 <li><strong>استفاده از ساختار داده <code>set</code> در پایتون:</strong> یادگیری نحوه ساخت مجموعه‌ها و انجام عملیات روی آن‌ها.</li>
#                 <li><strong>حل مسائل واقعی:</strong> کاربرد مفاهیم نظریه مجموعه‌ها در مسائلی که از زندگی روزمره گرفته شده‌اند.</li>
#             </ul>
#         </font>
#     </p>
# </div>
#
# <div dir="rtl">
#     <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#         <font face="vazir" size=3>
#             <strong>اهداف یادگیری:</strong>
#             <ul>
#                 <li>درک مفاهیم اساسی نظریه مجموعه‌ها.</li>
#                 <li>پیاده‌سازی عملیات مجموعه‌ای در پایتون.</li>
#                 <li>کاربرد مفاهیم نظریه مجموعه‌ها در حل مسائل واقعی.</li>
#             </ul>
#             با تکمیل این تمرین، شما نه تنها مهارت‌های خود را در زمینه نظریه مجموعه‌ها توسعه می‌دهید، بلکه تجربه کدنویسی خود را نیز بهبود بخشید. امیدواریم این تمرین برای شما مفید و جالب باشد!  <br>
#             <strong>بیایید شروع کنیم!</strong>
#         </font>
#     </p>
# </div>

# %% [markdown]
# <div dir="rtl">
#     <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
#         <font face="vazir" color="#0099cc">
#             بخش اول: ساخت مجموعه از یک لیست
#         </font>
#     </h3>
#     <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#         <font face="vazir" size=3>
#             در این بخش، قصد داریم یک تابع طراحی کنیم که یک لیست را به عنوان ورودی دریافت کرده و آن را به یک مجموعه (<code>set</code>) تبدیل کند. هدف از این کار حذف عناصر تکراری موجود در لیست است و یک مجموعه شامل عناصر منحصر به فرد به دست آوریم.
#             <br>
#             شما باید یک تابع به نام <code>create_set</code> بنویسید که:
#             <ul>
#                 <li>یک لیست به عنوان ورودی دریافت کند.</li>
#                 <li>عناصر تکراری لیست را حذف کرده و آن را به یک مجموعه تبدیل کند.</li>
#                 <li>مجموعه حاصل را به عنوان خروجی بگرداند.</li>
#             </ul>
#             توجه داشته باشید که مجموعه‌ها در پایتون از تکرار عناصر پشتیبانی نمی‌کنند، بنابراین این ویژگی را می‌توانید به صورت خودکار از ساختار داده <code>set</code> استفاده کنید.
#         </font>
#     </p>
# </div>

# %%
def create_set(input_ls):
    pass #to_do

# %% [markdown]
# <div dir="rtl">
#     <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
#         <font face="vazir" color="#0099cc">
#             بخش دوم: پیاده‌سازی عملیات مجموعه‌ای
#         </font>
#     </h3>
#     <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#         <font face="vazir" size=3>
#             در این بخش، قصد داریم توابعی را برای انجام عملیات مجموعه‌ای مانند اجتماع، اشتراک، تفاضل و متمم پیاده‌سازی کنیم. هر یک از این توابع باید دو مجموعه را به عنوان ورودی دریافت کرده و نتیجه عملیات مورد نظر را به صورت یک مجموعه جدید برگرداند (<code>return</code> کند).
#             <br>
#             شما باید چهار تابع زیر را پیاده‌سازی کنید:
#             <ul>
#                 <li><strong>تابع <code>union</code>:</strong> این تابع باید دو مجموعه را به عنوان ورودی دریافت کرده و اجتماع آنها را محاسبه کند.</li>
#                 <li><strong>تابع <code>intersection</code>:</strong> این تابع باید دو مجموعه را به عنوان ورودی دریافت کرده و اشتراک آنها را محاسبه کند.</li>
#                 <li><strong>تابع <code>difference</code>:</strong> این تابع باید دو مجموعه را به عنوان ورودی دریافت کرده و تفاضل مجموعه اول از مجموعه دوم را محاسبه کند.</li>
#                 <li><strong>تابع <code>complement</code>:</strong> این تابع باید یک مجموعه و یک مجموعه جهانی را به عنوان ورودی دریافت کرده و متمم مجموعه نسبت به مجموعه جهانی را محاسبه کند.</li>
#             </ul>
#             توجه داشته باشید که در پیاده‌سازی این توابع، از ساختار داده <code>set</code> در پایتون استفاده کنید و عملیات مربوطه را به طور مستقیم اجرا کنید.
#         </font>
#     </p>
# </div>

# %%
def union(first_set, second_set):
    pass #to_do
def intersection(first_set, second_set):
    pass #to_do
def difference(first_set, second_set):
    pass #to_do
def complenment(universal_set, first_set):
    pass #to_do

# %% [markdown]
# <div dir="rtl">
#     <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
#         <font face="vazir" color="#0099cc">
#             بخش سوم: پیاده‌سازی توابع بررسی مجموعه‌ها
#         </font>
#     </h3>
#     <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#         <font face="vazir" size=3>
#             در این بخش، قصد داریم توابعی را برای بررسی ویژگی‌های مختلف مجموعه‌ها پیاده‌سازی کنیم. این توابع شامل بررسی خالی بودن مجموعه، بررسی عضویت یک عنصر، بررسی زیرمجموعه بودن، و محاسبه تعداد اعضای مجموعه توانی است.
#             <br>
#             شما باید چهار تابع زیر را پیاده‌سازی کنید:
#             <ul>
#                 <li><strong>تابع <code>is_empty</code>:</strong> این تابع باید یک مجموعه را به عنوان ورودی دریافت کرده و بررسی کند که آیا مجموعه خالی است یا خیر (مقدار <code>True, False</code> برگرداند).</li>
#                 <li><strong>تابع <code>is_member</code>:</strong> این تابع باید یک مجموعه و یک عنصر را به عنوان ورودی دریافت کرده و بررسی کند که آیا عنصر داده‌شده عضو مجموعه است یا خیر(مقدار <code>True, False</code> برگرداند).</li>
#                 <li><strong>تابع <code>is_subset</code>:</strong> این تابع باید دو مجموعه را به عنوان ورودی دریافت کرده و بررسی کند که آیا مجموعه اول زیرمجموعه مجموعه دوم است یا خیر(مقدار <code>True, False</code> برگرداند).</li>
#                 <li><strong>تابع <code>power_set_number</code>:</strong> این تابع باید یک مجموعه را به عنوان ورودی دریافت کرده و تعداد اعضای مجموعه توانی آن را محاسبه کند (برابر با $2^n$ که در آن $n$ تعداد اعضای مجموعه است).</li>
#             </ul>
#             توجه داشته باشید که در پیاده‌سازی این توابع، از ویژگی‌ها و روش‌های موجود در ساختار داده <code>set</code> در پایتون استفاده کنید.
#         </font>
#     </p>
# </div>

# %%
def is_empty(the_set):
    pass #to_do
def is_member(the_set, element):
    pass #to_do
def is_subset(first_set, second_set):
    pass #to_do
def power_set_number(the_set):
    pass #to_do

# %% [markdown]
# <div dir="rtl">
#     <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
#         <font face="vazir" color="#0099cc">
#             بخش چهارم: تست و ارزیابی توابع
#         </font>
#     </h3>
#     <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#         <font face="vazir" size=3>
#             در این بخش، قصد داریم توابع پیاده‌سازی‌شده را با استفاده از مثال‌های مختلف آزمایش کنیم. هدف از این مرحله، بررسی درستی و دقت توابع است.
#             <br>
#             شما باید:
#             <ul>
#                 <li>یک یا چند مجموعه نمونه تعریف کنید (مانند <code>set_A</code> و <code>set_B</code>).</li>
#                 <li>توابع پیاده‌سازی‌شده را با استفاده از این مجموعه‌ها تست کنید.</li>
#                 <li>نتایج حاصل از هر تابع را چک کرده و صحت آن را بررسی کنید.</li>
#             </ul>
#             به عنوان مثال:
#             <ul>
#                 <li>برای تابع <code>union</code>، می‌توانید دو مجموعه را تعریف کرده و اجتماع آنها را محاسبه کنید.</li>
#                 <li>برای تابع <code>is_member</code>، می‌توانید یک عنصر را بررسی کنید که آیا عضو مجموعه است یا خیر.</li>
#                 <li>برای تابع <code>power_set_number</code>، می‌توانید تعداد اعضای مجموعه توانی یک مجموعه را محاسبه کرده و نتیجه را با انتظار شما مقایسه کنید.</li>
#             </ul>
#             توجه داشته باشید که نتایج حاصل از هر تابع باید با منطق مجموعه‌ها سازگار باشد.
#         </font>
#     </p>
# </div>

# %%
#to_do

# %% [markdown]
# <div dir="rtl">
#     <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
#         <font face="vazir" color="#0099cc">
#             بخش پنجم: تهیه فایل حاوی توابع
#         </font>
#     </h3>
#     <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#         <font face="vazir" size=3>
#             در این بخش، ما به صورت خودکار تمام توابع پیاده‌سازی‌شده را در یک فایل پایتون جداگانه به نام <code>solution_functions.py</code> ذخیره کرده‌ایم. این کار با استفاده از ماژول <code>inspect</code> انجام شده است، به طوری که کد منبع هر تابع استخراج و به فایل مربوطه اضافه شده است.
#             <br>
#             هدف از این مرحله، سازماندهی بهتر کد و امکان استفاده مجدد از توابع در پروژه‌های دیگر است. فایل تهیه‌شده حاوی تمام توابع مورد نیاز (مانند <code>create_set</code>, <code>union</code>, <code>intersection</code>, و غیره) است و آماده استفاده می‌باشد.
#             <br>
#             بنابراین، شما می‌توانید از این فایل در برنامه‌های بعدی خود استفاده کنید (بدون نیاز به پیاده‌سازی مجدد توابع).
#         </font>
#     </p>
# </div>

# %%
import inspect

# Save the functions to a .py file
with open("solution_functions.py", "w") as f:
    f.write(inspect.getsource(create_set))
    f.write("\n")  # Add newline for readability
    f.write(inspect.getsource(union))
    f.write("\n")  # Add newline for readability
    f.write(inspect.getsource(intersection))
    f.write("\n")  # Add newline for readability
    f.write(inspect.getsource(difference))
    f.write("\n")  # Add newline for readability
    f.write(inspect.getsource(complenment))
    f.write("\n")  # Add newline for readability
    f.write(inspect.getsource(is_empty))
    f.write("\n")  # Add newline for readability
    f.write(inspect.getsource(is_subset))
    f.write("\n")  # Add newline for readability
    f.write(inspect.getsource(is_member))
    f.write("\n")  # Add newline for readability
    f.write(inspect.getsource(power_set_number))

# %% [markdown]
# <div dir="rtl">
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
# </div>
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا در صورت نیاز به پشتیبانی امکان بررسی کد شما وجود داشته باشد.
# </font>
# </p>

# %%
import zipfile
import joblib

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)


file_names = [ 'solution_functions.py', 'Hands-On Set Theory Building and Manipulating Sets in Python.ipynb']
compress(file_names)
