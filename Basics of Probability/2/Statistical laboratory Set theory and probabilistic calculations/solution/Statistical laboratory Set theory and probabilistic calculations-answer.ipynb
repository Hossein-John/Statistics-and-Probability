# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# آزمایشگاه آماری: نظریه مجموعه‌ها و محاسبات احتمالاتی
# </font>
# </h1>
#
# <div dir="rtl">
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# نظریه مجموعه‌ها و احتمال دو پایه اصلی در زمینه علوم داده، آمار و هوش مصنوعی هستند. با ترکیب این دو مفهوم، می‌توانید به حل مسائل پیچیده‌ای در حوزه تحلیل داده‌ها و تصمیم‌گیری مبتنی بر داده بپردازید. در این تمرین، قصد داریم که عملیات مجموعه‌ای را با محاسبات احتمالاتی ترکیب کنیم و نحوه کاربرد آن‌ها را در مسائل واقعی یاد بگیریم.
# </div>
# </font>
# </p>
#
# <div dir="rtl">
#     <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
#         <font face="vazir" color="#0099cc">
#             هدف از تمرین:
#         </font>
#     </h3>
#     <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#         <font face="vazir" size=3>
#             هدف اصلی این تمرین، آشنایی شما با ترکیب مفاهیم نظریه مجموعه‌ها و احتمال در محیط برنامه‌نویسی پایتون است. در این تمرین، شما با عملیات مجموعه‌ای مانند اجتماع، اشتراک، تفاضل و متمم، همچنین محاسبات احتمالاتی مانند احتمال پیشامد، احتمال شرطی، استقلال پیشامدها و قضیه بیز آشنا خواهید شد.<br>
#             پایتون به دلیل سادگی و قدرتمند بودن، ابزار مناسبی برای پیاده‌سازی این مفاهیم است. ما از ساختار داده‌ای <code>set</code> برای عملیات مجموعه‌ای و توابع مختلف برای محاسبات احتمالاتی استفاده خواهیم کرد.
#         </font>
#     </p>
# </div>
#
# <div dir="rtl">
#     <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
#         <font face="vazir" color="#0099cc">
#             ساختار تمرین:
#         </font>
#     </h3>
#     <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#         <font face="vazir" size=3>
#             این تمرین شامل سه بخش است:
#             <ol>
#                 <li><strong>بخش نظری:</strong> مرور مفاهیم اساسی نظریه مجموعه‌ها و احتمال.</li>
#                 <li><strong>بخش عملی - عملیات مجموعه‌ای:</strong> پیاده‌سازی توابع برای انجام عملیات مجموعه‌ای مانند اجتماع، اشتراک، تفاضل و متمم.</li>
#                 <li><strong>بخش عملی - محاسبات احتمالاتی:</strong> پیاده‌سازی توابع برای محاسبه احتمال پیشامد، احتمال شرطی، بررسی استقلال پیشامدها و اعمال قضیه بیز.</li>
#             </ol>
#         </font>
#     </p>
# </div>
#
# <div dir="rtl">
#     <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
#         <font face="vazir" color="#0099cc">
#             چه چیزی از این تمرین یاد می‌گیرید؟
#         </font>
#     </h3>
#     <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#         <font face="vazir" size=3>
#             <ul>
#                 <li><strong>مفاهیم اساسی نظریه مجموعه‌ها:</strong> اجتماع، اشتراک، تفاضل، متمم و مجموعه توانی.</li>
#                 <li><strong>مفاهیم اساسی احتمال:</strong> احتمال پیشامد، احتمال شرطی، استقلال پیشامدها و قضیه بیز.</li>
#                 <li><strong>استفاده از ساختار داده <code>set</code> در پایتون:</strong> یادگیری نحوه ساخت مجموعه‌ها و انجام عملیات روی آن‌ها.</li>
#                 <li><strong>حل مسائل واقعی:</strong> کاربرد ترکیب مفاهیم نظریه مجموعه‌ها و احتمال در مسائلی که از زندگی روزمره گرفته شده‌اند.</li>
#             </ul>
#         </font>
#     </p>
# </div>
#
# <div dir="rtl">
#     <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#         <font face="vazir" size=3>
#             <strong>اهداف یادگیری:</strong>
#             <ul>
#                 <li>درک مفاهیم اساسی نظریه مجموعه‌ها و احتمال.</li>
#                 <li>پیاده‌سازی عملیات مجموعه‌ای و محاسبات احتمالاتی در پایتون.</li>
#                 <li>کاربرد ترکیب مفاهیم نظریه مجموعه‌ها و احتمال در حل مسائل واقعی.</li>
#             </ul>
#             با تکمیل این تمرین، شما نه تنها مهارت‌های خود را در زمینه نظریه مجموعه‌ها و احتمال توسعه می‌دهید، بلکه تجربه کدنویسی خود را نیز بهبود بخشید. آمیدواریم این تمرین برای شما مفید و جالب باشد!  <br>
#             <strong>بیایید شروع کنیم!</strong>
#         </font>
#     </p>
# </div>

# %% [markdown]
# <div dir="rtl">
#     <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
#         <font face="vazir" color="#0099cc">
#             بخش اول: پیاده‌سازی توابع مجموعه‌ای
#         </font>
#     </h3>
#     <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#         <font face="vazir" size=3>
#             در این بخش، قصد داریم تمام توابع مربوط به عملیات مجموعه‌ای که در تمرین قبلی معرفی شدند را به صورت تابع‌های مستقل (Functional) پیاده‌سازی کنیم. این توابع شامل عملیات پایه‌ای مانند بررسی خالی بودن مجموعه، بررسی عضویت، زیرمجموعه بودن، محاسبه تعداد اعضای مجموعه توانی، اجتماع، اشتراک، تفاضل و متمم هستند.
#             <br>
#             شما باید توابع زیر را پیاده‌سازی کنید:
#             <ul>
#                 <li><strong>تابع `create_set`:</strong> یک لیست را به عنوان ورودی دریافت کرده و آن را به یک مجموعه تبدیل کند.</li>
#                 <li><strong>تابع `is_empty`:</strong> بررسی کند که آیا مجموعه تهی است یا خیر.</li>
#                 <li><strong>تابع `is_member`:</strong> بررسی کند که آیا عنصر داده‌شده عضو مجموعه است یا خیر.</li>
#                 <li><strong>تابع `is_subset`:</strong> بررسی کند که آیا مجموعه اول زیرمجموعه مجموعه دوم است یا خیر.</li>
#                 <li><strong>تابع `power_set_number`:</strong> تعداد اعضای مجموعه توانی مجموعه داده‌شده را محاسبه کند.</li>
#                 <li><strong>تابع `union`:</strong> اجتماع دو مجموعه را محاسبه کند.</li>
#                 <li><strong>تابع `intersection`:</strong> اشتراک دو مجموعه را محاسبه کند.</li>
#                 <li><strong>تابع `difference`:</strong> تفاضل دو مجموعه را محاسبه کند.</li>
#                 <li><strong>تابع `complement`:</strong> متمم مجموعه نسبت به مجموعه جهانی را محاسبه کند.</li>
#             </ul>
#             توجه داشته باشید که باید از ساختار داده `set` در پایتون برای پیاده‌سازی این توابع استفاده کنید و هر تابع باید فقط وظیفه مشخصی را انجام دهد. این توابع پایه‌ای هستند و خروجی آن‌ها در بخش‌های بعدی تمرین مورد استفاده قرار خواهد گرفت.
#         </font>
#     </p>
# </div>

# %%
def create_set(input_ls):
    """تبدیل لیست ورودی به یک مجموعه بدون عناصر تکراری."""
    return set(input_ls)

def union(first_set, second_set):
    """انجام عملیات اجتماع بین دو مجموعه."""
    return first_set.union(second_set)

def intersection(first_set, second_set):
    """انجام عملیات اشتراک بین دو مجموعه."""
    return first_set.intersection(second_set)

def difference(first_set, second_set):
    """انجام عملیات تفاضل بین دو مجموعه (first_set - second_set)."""
    return first_set.difference(second_set)

def complement(universal_set, first_set):
    """محاسبه متمم مجموعه first_set نسبت به مجموعه جهانی universal_set."""
    return universal_set.difference(first_set)

def is_empty(the_set):
    """بررسی خالی بودن یک مجموعه."""
    return len(the_set) == 0

def is_member(the_set, element):
    """بررسی عضویت عنصر element در مجموعه the_set."""
    return element in the_set

def is_subset(first_set, second_set):
    """بررسی اینکه first_set زیرمجموعه second_set است یا خیر."""
    return first_set.issubset(second_set)

def power_set_number(the_set):
    """محاسبه تعداد اعضای مجموعه توانی یک مجموعه."""
    return 2 ** len(the_set)

# %% [markdown]
# <div dir="rtl">
#     <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
#         <font face="vazir" color="#0099cc">
#             بخش دوم: پیاده‌سازی توابع محاسبات احتمالاتی
#         </font>
#     </h3>
#     <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#         <font face="vazir" size=3>
#             در این بخش، قصد داریم توابع مربوط به محاسبات احتمالاتی را پیاده‌سازی کنیم. این توابع شامل محاسبه احتمال یک پیشامد، احتمال شرطی، بررسی استقلال پیشامدها و اعمال قضیه بیز هستند. این توابع به ما اجازه می‌دهند تا با استفاده از مفاهیم نظریه مجموعه‌ها، محاسبات احتمالاتی را به صورت عملکردی (Functional) پیاده‌سازی کنیم.
#             <br>
#             شما باید توابع زیر را پیاده‌سازی کنید:
#             <ul>
#                 <li>
#                     <strong>تابع <code>probability_of_event</code>:</strong><br>
#                     <em>مثال:</em>
#                     <code>probability_of_event({1, 2}, {1, 2, 3, 4, 5, 6}) #return 0.333</code><br>
#                     - اولین مجموعه (<code>{1, 2}</code>): مجموعه پیشامد.<br>
#                     - دومین مجموعه (<code>{1, 2, 3, 4, 5, 6}</code>): فضای نمونه (مجموعه جهانی).<br>
#                     - خروجی: $ P(A) = \frac{|A|}{|U|} = \frac{2}{6} = 0.333 $.<br>
#                     <details class="blue">
#                         <summary>
#                             <strong>یادآوری مفهوم</strong>
#                         </summary>
#                         احتمال یک پیشامد $ A $ به صورت زیر تعریف می‌شود:
#                         $$
#                         P(A) = \frac{|A|}{|U|}
#                         $$<br>
#                         که در آن:<br>
#                         - $ |A| $: تعداد عناصر مجموعه پیشامد $ A $.<br>
#                         - $ |U| $: تعداد عناصر فضای نمونه (مجموعه جهانی $ U $).<br>
#                     </details>
#                 </li>
#                 <br>
#                 <li>
#                     <strong>تابع <code>conditional_probability</code>:</strong><br>
#                     <em>مثال:</em>
#                     <code>conditional_probability({1, 2}, {1, 2, 3, 4}) #return 0.5</code><br>
#                     - اولین مجموعه (<code>{1, 2}</code>): مجموعه پیشامد $ A $.<br>
#                     - دومین مجموعه (<code>{1, 2, 3, 4}</code>): مجموعه پیشامد $ B $.<br>
#                     - خروجی: $ P(A|B) = \frac{|A \cap B|}{|B|} = \frac{2}{4} = 0.5 $.<br>
#                     <details class="blue">
#                         <summary>
#                             <strong>یادآوری مفهوم</strong>
#                         </summary>
#                         احتمال شرطی $ P(A|B) $ به صورت زیر تعریف می‌شود:
#                         $$
#                         P(A|B) = \frac{|A \cap B|}{|B|}
#                         $$<br>
#                         که در آن:<br>
#                         - $ |A \cap B| $: تعداد عناصر مشترک بین مجموعه‌های $ A $ و $ B $.<br>
#                         - $ |B| $: تعداد عناصر مجموعه $ B $.<br>
#                     </details>
#                 </li>
#                 <br>
#                 <li>
#                     <strong>تابع <code>are_independent</code>:</strong><br>
#                     <em>مثال:</em>
#                     <code>are_independent({1, 2}, {1, 3, 5}, {1, 2, 3, 4, 5, 6}) #retrun True or False</code><br>
#                     - اولین مجموعه (<code>{1, 2}</code>): مجموعه پیشامد $ A $.<br>
#                     - دومین مجموعه (<code>{1, 3, 5}</code>): مجموعه پیشامد $ B $.<br>
#                     - سومین مجموعه (<code>{1, 2, 3, 4, 5, 6}</code>): فضای نمونه (مجموعه جهانی).<br>
#                     - خروجی: True (چون $ P(A \cap B) = P(A) \cdot P(B) $).<br>
#                     <details class="blue">
#                         <summary>
#                             <strong>یادآوری مفهوم</strong>
#                         </summary>
#                         دو پیشامد $ A $ و $ B $ مستقلند اگر و فقط اگر:
#                         $$
#                         P(A \cap B) = P(A) \cdot P(B)
#                         $$<br>
#                         که در آن:<br>
#                         - $ P(A \cap B) $: احتمال اشتراک دو پیشامد $ A $ و $ B $.<br>
#                         - $ P(A) $: احتمال پیشامد $ A $.<br>
#                         - $ P(B) $: احتمال پیشامد $ B $.<br>
#                         برای بررسی استقلال، ابتدا اشتراک $ A $ و $ B $ را محاسبه کرده و سپس نسبت آن را با حاصلضرب احتمالات $ A $ و $ B $ مقایسه کنید.
#                     </details>
#                 </li>
#                 <br>
#                 <li>
#                     <strong>تابع <code>bayes_theorem</code>:</strong><br>
#                     <em>مثال:</em>
#                     <code>bayes_theorem({1, 2}, {1, 3, 5}, {1, 2, 3, 4, 5, 6}) #return 0.5</code><br>
#                     - اولین مجموعه (<code>{1, 2}</code>): مجموعه پیشامد $ A $.<br>
#                     - دومین مجموعه (<code>{1, 3, 5}</code>): مجموعه پیشامد $ B $.<br>
#                     - سومین مجموعه (<code>{1, 2, 3, 4, 5, 6}</code>): فضای نمونه (مجموعه جهانی).<br>
#                     - خروجی: $ P(B|A) = \frac{P(A|B) \cdot P(B)}{P(A)} = \frac{\frac{1}{3} \cdot \frac{3}{6}}{\frac{2}{6}} = 0.5 $.<br>
#                     <details class="blue">
#                         <summary>
#                             <strong>یادآوری مفهوم</strong>
#                         </summary>
#                         قضیه بیز به صورت زیر بیان می‌شود:
#                         $$
#                         P(B|A) = \frac{P(A|B) \cdot P(B)}{P(A)}
#                         $$<br>
#                         که در آن:<br>
#                         - $ P(A|B) $: احتمال شرطی $ A $ به شرط $ B $.<br>
#                         - $ P(B) $: احتمال پیشامد $ B $.<br>
#                         - $ P(A) $: احتمال پیشامد $ A $.<br>
#                         برای محاسبه $ P(B|A) $، ابتدا باید احتمال شرطی $ P(A|B) $ و احتمالات $ P(A) $ و $ P(B) $ را محاسبه کنید.
#                     </details>
#                 </li>
#             </ul>
#             توجه داشته باشید که برای پیاده‌سازی این توابع، باید از توابع مجموعه‌ای که در بخش اول پیاده‌سازی کردید، استفاده کنید. به عنوان مثال، برای محاسبه احتمال یک پیشامد، نسبت تعداد عناصر مجموعه پیشامد به تعداد عناصر مجموعه جهانی را محاسبه می‌کنیم. همچنین، برای محاسبه احتمال شرطی و اعمال قضیه بیز، از عملیات مجموعه‌ای مانند اشتراک استفاده می‌کنیم.
#         </font>
#     </p>
# </div>

# %%
def probability_of_event(event_set, sample_space) -> float:
    """محاسبه احتمال یک پیشامد event_set در فضای نمونه sample_space."""
    if len(sample_space) == 0:
        raise ValueError("فضای نمونه نباید خالی باشد.")
    return len(event_set) / len(sample_space)

def conditional_probability(event_A, event_B) -> float:
    """محاسبه احتمال شرطی P(A|B) با استفاده از اشتراک دو مجموعه A و B."""
    if len(event_B) == 0:
        raise ValueError("مجموعه B نباید خالی باشد.")
    intersection_set = event_A.intersection(event_B)
    return len(intersection_set) / len(event_B)

def are_independent(event_A, event_B, sample_space) -> bool:
    """بررسی استقلال دو پیشامد A و B در فضای نمونه sample_space."""
    prob_A = probability_of_event(event_A, sample_space)
    prob_B = probability_of_event(event_B, sample_space)
    intersection_set = event_A.intersection(event_B)
    prob_intersection = len(intersection_set) / len(sample_space)
    return abs(prob_intersection - (prob_A * prob_B)) < 1e-9  # بررسی تقریبی برابری

def bayes_theorem(event_A, event_B, sample_space) -> float:
    """اعمال قضیه بیز برای محاسبه P(B|A)."""
    if len(event_A) == 0:
        raise ValueError("مجموعه A نباید خالی باشد.")
    prob_A = probability_of_event(event_A, sample_space)
    prob_B = probability_of_event(event_B, sample_space)
    intersection_set = event_A.intersection(event_B)
    prob_intersection = len(intersection_set) / len(sample_space)
    return (prob_intersection / prob_A) if prob_A != 0 else 0

# %% [markdown]
# <div dir="rtl">
#     <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
#         <font face="vazir" color="#0099cc">
#             بخش سوم: تست و ارزیابی توابع
#         </font>
#     </h3>
#     <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#         <font face="vazir" size=3>
#             در این بخش، قصد داریم توابع پیاده‌سازی‌شده را با استفاده از مثال‌های مختلف تست کنیم و نتایج حاصل از آن‌ها را بررسی کنیم. هدف از این مرحله، تأیید درست‌کاری توابع و بررسی صحت محاسبات است.
#             <br>
#             برای تست توابع، می‌توانید از مجموعه‌های مختلف و مسائل واقعی استفاده کنید. در ادامه، چند مثال تست برای هر تابع ارائه شده است:
#             <ul>
#                 <li>
#                     <strong>تابع <code>probability_of_event</code>:</strong><br>
#                     <em>مثال تست:</em>
#                     <code>probability_of_event({1, 2, 3}, {1, 2, 3, 4, 5, 6})</code><br>
#                     - اولین مجموعه (<code>{1, 2, 3}</code>): مجموعه پیشامد.<br>
#                     - دومین مجموعه (<code>{1, 2, 3, 4, 5, 6}</code>): فضای نمونه (مجموعه جهانی).<br>
#                     - خروجی: $ P(A) = \frac{|A|}{|U|} = \frac{3}{6} = 0.5 $.<br>
#                     <details class="blue">
#                         <summary>
#                             <strong>راهنمایی برای تست</strong>
#                         </summary>
#                         برای تست این تابع، می‌توانید مجموعه‌های مختلفی با اندازه‌های متغیر امتحان کنید. مثلاً:<br>
#                         - فضای نمونه: <code>{1, 2, 3, 4, 5, 6, 7, 8}</code>.<br>
#                         - مجموعه پیشامد: <code>{2, 4, 6}</code>.<br>
#                         - نتیجه منتظره: $ P(A) = \frac{3}{8} = 0.375 $.<br>
#                         اطمینان حاصل کنید که خروجی تابع با محاسبات دستی سازگار است.
#                     </details>
#                 </li>
#                 <br>
#                 <li>
#                     <strong>تابع <code>conditional_probability</code>:</strong><br>
#                     <em>مثال تست:</em>
#                     <code>conditional_probability({1, 2}, {1, 2, 3, 4})</code><br>
#                     - اولین مجموعه (<code>{1, 2}</code>): مجموعه پیشامد $ A $.<br>
#                     - دومین مجموعه (<code>{1, 2, 3, 4}</code>): مجموعه پیشامد $ B $.<br>
#                     - خروجی: $ P(A|B) = \frac{|A \cap B|}{|B|} = \frac{2}{4} = 0.5 $.<br>
#                     <details class="blue">
#                         <summary>
#                             <strong>راهنمایی برای تست</strong>
#                         </summary>
#                         برای تست این تابع، می‌توانید مجموعه‌های مختلفی با اشتراک‌های متغیر امتحان کنید. مثلاً:<br>
#                         - مجموعه $ A $: <code>{2, 4, 6}</code>.<br>
#                         - مجموعه $ B $: <code>{1, 2, 3, 4}</code>.<br>
#                         - نتیجه منتظره: $ P(A|B) = \frac{|A \cap B|}{|B|} = \frac{2}{4} = 0.5 $.<br>
#                         اطمینان حاصل کنید که تابع به درستی اشتراک دو مجموعه را محاسبه کرده و نسبت را به درستی برمی‌گرداند.
#                     </details>
#                 </li>
#                 <br>
#                 <li>
#                     <strong>تابع <code>are_independent</code>:</strong><br>
#                     <em>مثال تست:</em>
#                     <code>are_independent({1, 2}, {3, 4}, {1, 2, 3, 4, 5, 6})</code><br>
#                     - اولین مجموعه (<code>{1, 2}</code>): مجموعه پیشامد $ A $.<br>
#                     - دومین مجموعه (<code>{3, 4}</code>): مجموعه پیشامد $ B $.<br>
#                     - سومین مجموعه (<code>{1, 2, 3, 4, 5, 6}</code>): فضای نمونه (مجموعه جهانی).<br>
#                     - خروجی: True (چون $ P(A \cap B) = P(A) \cdot P(B) $).<br>
#                     <details class="blue">
#                         <summary>
#                             <strong>راهنمایی برای تست</strong>
#                         </summary>
#                         برای تست این تابع، می‌توانید مجموعه‌های مستقل و وابسته را بررسی کنید. مثلاً:<br>
#                         - مجموعه $ A $: <code>{1, 2}</code>.<br>
#                         - مجموعه $ B $: <code>{3, 4}</code>.<br>
#                         - فضای نمونه: <code>{1, 2, 3, 4, 5, 6}</code>.<br>
#                         - نتیجه منتظره: True (چون اشتراک $ A $ و $ B $ تهی است و $ P(A \cap B) = P(A) \cdot P(B) $).<br>
#                         همچنین، می‌توانید مجموعه‌های وابسته را نیز تست کنید تا اطمینان حاصل کنید که تابع نتیجه صحیح را برمی‌گرداند.
#                     </details>
#                 </li>
#                 <br>
#                 <li>
#                     <strong>تابع <code>bayes_theorem</code>:</strong><br>
#                     <em>مثال تست:</em>
#                     <code>bayes_theorem({1, 2}, {1, 3, 5}, {1, 2, 3, 4, 5, 6})</code><br>
#                     - اولین مجموعه (<code>{1, 2}</code>): مجموعه پیشامد $ A $.<br>
#                     - دومین مجموعه (<code>{1, 3, 5}</code>): مجموعه پیشامد $ B $.<br>
#                     - سومین مجموعه (<code>{1, 2, 3, 4, 5, 6}</code>): فضای نمونه (مجموعه جهانی).<br>
#                     - خروجی: $ P(B|A) = \frac{P(A|B) \cdot P(B)}{P(A)} = \frac{\frac{1}{3} \cdot \frac{3}{6}}{\frac{2}{6}} = 0.5 $.<br>
#                     <details class="blue">
#                         <summary>
#                             <strong>راهنمایی برای تست</strong>
#                         </summary>
#                         برای تست این تابع، می‌توانید مجموعه‌های مختلفی با احتمالات مشخص امتحان کنید. مثلاً:<br>
#                         - مجموعه $ A $: <code>{1, 2}</code>.<br>
#                         - مجموعه $ B $: <code>{1, 3, 5}</code>.<br>
#                         - فضای نمونه: <code>{1, 2, 3, 4, 5, 6}</code>.<br>
#                         - نتیجه منتظره: $ P(B|A) = 0.5 $.<br>
#                         اطمینان حاصل کنید که تابع به درستی احتمال شرطی را براساس قضیه بیز محاسبه می‌کند.
#                     </details>
#                 </li>
#             </ul>
#             در پایان، می‌توانید نتایج حاصل از هر تابع را با محاسبات دستی مقایسه کنید و صحت عملکرد توابع را بررسی کنید. این کار به شما کمک می‌کند تا اطمینان حاصل کنید که تمام توابع به درستی پیاده‌سازی شده‌اند.
#         </font>
#     </p>
# </div>

# %%
#to_do

# مثال‌های تست
sample_space = {1, 2, 3, 4, 5, 6}
event_A = {1, 2}
event_B = {1, 3, 5}

# ساخت مجموعه
print(create_set([1, 2, 2, 3, 4]))  # {1, 2, 3, 4}

# اجتماع
print(union(event_A, event_B))  # {1, 2, 3, 5}

# اشتراک
print(intersection(event_A, event_B))  # {1}

# تفاضل
print(difference(event_A, event_B))  # {2}

# متمم
universal_set = {1, 2, 3, 4, 5, 6}
print(complement(universal_set, event_A))  # {3, 4, 5, 6}

# خالی بودن
print(is_empty(event_A))  # False

# عضویت
print(is_member(event_A, 2))  # True

# زیرمجموعه بودن
print(is_subset(event_A, sample_space))  # True

# تعداد اعضای مجموعه توانی
print(power_set_number(event_A))  # 4

# احتمال پیشامد
print(probability_of_event(event_A, sample_space))  # 0.333...

# احتمال شرطی
print(conditional_probability(event_A, event_B))  # 0.333...

# استقلال پیشامدها
print(are_independent(event_A, event_B, sample_space))  # True

# قضیه بیز
print(bayes_theorem(event_A, event_B, sample_space))  # 0.5
# Out:
# {1, 2, 3, 4}
# {1, 2, 3, 5}
# {1}
# {2}
# {3, 4, 5, 6}
# False
# True
# True
# 4
# 0.3333333333333333
# 0.3333333333333333
# True
# 0.5

# %% [markdown]
# <div dir="rtl">
#     <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
#         <font face="vazir" color="#0099cc">
#             بخش چهارم: تهیه فایل حاوی توابع
#         </font>
#     </h3>
#     <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#         <font face="vazir" size=3>
#             در این بخش، ما به صورت خودکار تمام توابع پیاده‌سازی‌شده را در یک فایل پایتون جداگانه به نام <code>solution_functions.py</code> ذخیره کرده‌ایم. این کار با استفاده از ماژول <code>inspect</code> انجام شده است، به طوری که کد منبع هر تابع استخراج و به فایل مربوطه اضافه شده است.
#             <br>
#             هدف از این مرحله، سازماندهی بهتر کد و امکان استفاده مجدد از توابع در پروژه‌های دیگر است. فایل تهیه‌شده حاوی تمام توابع مورد نیاز (مانند <code>create_set</code>, <code>union</code>, <code>intersection</code>, و غیره) است و آماده استفاده می‌باشد.
#             <br>
#             بنابراین، شما می‌توانید از این فایل در برنامه‌های بعدی خود استفاده کنید بدون نیاز به مجدد پیاده‌سازی توابع.
#         </font>
#     </p>
# </div>

# %%
import inspect

# Save the functions to a .py file
with open("solution_functions.py", "w", encoding="utf-8") as f:
    f.write(inspect.getsource(create_set))
    f.write("\n")  # Add newline for readability
    f.write(inspect.getsource(union))
    f.write("\n")  # Add newline for readability
    f.write(inspect.getsource(intersection))
    f.write("\n")  # Add newline for readability
    f.write(inspect.getsource(difference))
    f.write("\n")  # Add newline for readability
    f.write(inspect.getsource(complement))
    f.write("\n")  # Add newline for readability
    f.write(inspect.getsource(is_empty))
    f.write("\n")  # Add newline for readability
    f.write(inspect.getsource(is_subset))
    f.write("\n")  # Add newline for readability
    f.write(inspect.getsource(is_member))
    f.write("\n")  # Add newline for readability
    f.write(inspect.getsource(power_set_number))
    f.write("\n")  # Add newline for readability
    f.write(inspect.getsource(probability_of_event))
    f.write("\n")  # Add newline for readability
    f.write(inspect.getsource(conditional_probability))
    f.write("\n")  # Add newline for readability
    f.write(inspect.getsource(are_independent))
    f.write("\n")  # Add newline for readability
    f.write(inspect.getsource(bayes_theorem))

# %% [markdown]
# <div dir="rtl">
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
# </div>
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا در صورت نیاز به پشتیبانی امکان بررسی کد شما وجود داشته باشد.
# </font>
# </p>

# %%
import zipfile
import joblib

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)


file_names = [ 'solution_functions.py', 'Statistical laboratory Set theory and probabilistic calculations.ipynb']
compress(file_names)
# Out:
# File Paths:
# ['solution_functions.py', 'Statistical laboratory Set theory and probabilistic calculations.ipynb']
