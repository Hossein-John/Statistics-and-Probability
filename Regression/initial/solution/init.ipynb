# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# کافه‌ی اصغر
# </font>
# </h1>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# اصغر مدتی است که رویای راه‌اندازی یک کافه را در سر دارد. او بودجه محدودی دارد و تصمیم گرفته است که بخش عمده‌ای از سرمایه خود را صرف خرید <b>بهترین دستگاه قهوه‌ساز بازار</b> کند، اما هیچ هزینه‌ای برای <b>تبلیغات</b> کنار نگذارد. اصغر معتقد است که کیفیت قهوه حرف اول را می‌زند و مشتریان خودشان راهشان را به سمت کافه او پیدا خواهند کرد.
# <br><br>
# اما <b>زن اصغر</b> دیدگاه متفاوتی دارد! او باور دارد که <b>تبلیغات نقش اساسی در جذب مشتریان دارد</b> و بدون آن، حتی بهترین قهوه دنیا هم فروش چندانی نخواهد داشت. برای اثبات حرفش، او داده‌هایی از <b>قیمت دستگاه‌های قهوه‌ساز، هزینه تبلیغات و میزان فروش</b> چندین کافه را جمع‌آوری کرده است.
# <br><br>
# اما مشکل اینجاست که زن اصغر دانش آماری چندانی ندارد. او از شما کمک می‌خواهد تا <b>با استفاده از تحلیل آماری و رگرسیون خطی</b> بررسی کنید که <b>کدام متغیر (قیمت دستگاه قهوه‌ساز یا هزینه تبلیغات) تأثیر بیشتری بر میزان فروش دارد</b>.
# </font>
# </p>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# در ابتدا کتابخانه‌های لازم را وارد می‌کنیم.
# </font>
# </p>

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import linregress

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# نخست مجموعه‌داده‌ای که در فایل <code>coffee_ad_sales_data.csv</code> قرار داده شده است را بخوانید.
# <br>
# در این مجموعه داده، اطلاعاتی از <b>۲۰۰ کافه</b> مختلف جمع‌آوری شده است که شامل <b>قیمت دستگاه قهوه‌ساز</b>، <b>هزینه تبلیغات</b> و <b>میزان فروش</b> آن‌ها می‌باشد. هدف این داده‌ها بررسی تأثیر تبلیغات و قیمت دستگاه بر میزان فروش است.
# </font>
# </p>
#
# <p dir=rtl style="direction: rtl;text-align: center;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# <table dir=rtl style="width: 100%; border: 1px solid black; border-collapse: collapse; text-align: center;">
#   <tr style="background-color: #ff5733; color: white;">
#     <th style="padding: 10px; border: 1px solid white;">نام ستون</th>
#     <th style="padding: 10px; border: 1px solid white;">توضیح</th>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid black;"> <b>Coffee_Machine_Price</b> </td>
#     <td style="padding: 10px; border: 1px solid black;"> قیمت دستگاه قهوه‌ساز (بر حسب دلار) که توسط هر کافه خریداری شده است. </td>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid black;"> <b>Ad_Spend</b> </td>
#     <td style="padding: 10px; border: 1px solid black;"> هزینه‌ای که هر کافه برای تبلیغات صرف کرده است (بر حسب دلار). </td>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid black;"> <b>Sales</b> </td>
#     <td style="padding: 10px; border: 1px solid black;"> میزان فروش بر حسب تعداد نوشیدنی‌های فروخته‌شده. </td>
#   </tr>
# </table>
# </font>
# </p>

# %%
# TODO: Load the data
data = pd.read_csv('coffee_ad_sales_data.csv')
data.head()
# Out:
#    Coffee_Machine_Price  Ad_Spend      Sales
# 0                  1360      8158  45.128429
# 1                  4272     11248  66.079002
# 2                  3592      8400  53.296256
# 3                   966      4170  31.152027
# 4                  4926     10874  84.002455

# %%
# TODO: Perform linear regression analysis to examine the relationship between ad spend and sales


slope_ad, intercept_ad, r_value_ad, p_value_ad, std_err_ad = linregress(data['Ad_Spend'], data['Sales'])


# Calculate and display the R^2 value (coefficient of determination) for the ad spend regression
print(f'R^2 (Coefficient of Determination) for Ad Spend: {r_value_ad**2}')

# Display the p-value for the ad spend regression to check statistical significance
print(f'P-value for Ad Spend: {p_value_ad}')
# Out:
# R^2 (Coefficient of Determination) for Ad Spend: 0.9428613653365274
# P-value for Ad Spend: 5.032221004594803e-125

# %%
# TODO: Perform linear regression analysis to examine the relationship between coffee machine price and sales

slope_price, intercept_price, r_value_price, p_value_price, std_err_price = linregress(data['Coffee_Machine_Price'], data['Sales'])


# Calculate and display the R^2 value (coefficient of determination) for the coffee machine price regression
print(f'R^2 (Coefficient of Determination) for Coffee Machine Price: {r_value_price**2}')

# Display the p-value for the coffee machine price regression to check statistical significance
print(f'P-value for Coffee Machine Price: {p_value_price}')
# Out:
# R^2 (Coefficient of Determination) for Coffee Machine Price: 0.009750056549862286
# P-value for Coffee Machine Price: 0.16420206226047385

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# با توجه به نتایج دو آزمون به نظر شما اصغر بهتر است سرمایه خود را بر روی کدام مورد خرج کند. اگر نظر شما دستگاه قهوه‌ساز است، در متغیر ‌<code>choice</code> عبارت <code>coffee</code> را وارد کنید در غیر این صورت، در این متغیر عبارت <code>ad</code> را وارد کنید.
# </font>
# </p>

# %%
# TODO: which variable is worth the investment? Ad or Coffee Machine Price? if Ad is worth the investment, assign 'ad' to the variable choice, otherwise assign 'coffee'
choice = 'ad' if r_value_ad**2 > r_value_price**2 else 'coffee'
print(f'{choice} is worth the investment')
# Out:
# ad is worth the investment

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# با اجرای دو قطعه کد زیر می‌توانید نمودار پراکندگی با خط رگرسیون بین هر مورد با میزان فروش را مشاهده کنید.
# </font>
# </p>

# %%
# Display the scatter plot of the relationship between ad spend and sales
sns.regplot(x=data['Ad_Spend'], y=data['Sales'])
plt.xlabel('Advertising Spend')
plt.ylabel('Sales')
plt.title('Relationship between Advertising Spend and Sales')
plt.show()

# %%
# Display the scatter plot of the relationship between ad coffee machine price and sales
sns.regplot(x=data['Coffee_Machine_Price'], y=data['Sales'])
plt.xlabel('Coffee Machine Price')
plt.ylabel('Sales')
plt.title('Relationship between Coffee Machine Price and Sales')
plt.show()

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# حال اصغر از شما می‌خواهد که برای او پیشبینی کنید اگر ۳۰۰۰ دلار بر روی موردی که ارزش بیشتری دارد (دستگاه قهوه یا تبلیغات که با توجه به نتایج آزمون باید انتخاب کنید) هزینه کند چند لیوان قهوه در روز فروش خواهد داشت.
# جواب را به نزدیک‌ترین عدد صحیح رند کنید و در متغیر <code>cups_per_day</code> ذخیره کنید.
# </font>
# </p>

# %%
cups_per_day = round(slope_ad * 3000 + intercept_ad)
print(f'Predicted daily sales for 3000$ ad spend: {cups_per_day} cups')
# Out:
# Predicted daily sales for 3000$ ad spend: 24 cups

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا در صورت نیاز به پشتیبانی امکان بررسی کد شما وجود داشته باشد.
# </font>
# </p>

# %%
import zipfile
import joblib

joblib.dump(r_value_ad, "r_value_ad")
joblib.dump(r_value_price, "r_value_price")
joblib.dump(choice, "choice")
joblib.dump(cups_per_day, "cups_per_day")


def compress(file_names):
    print("File Paths:")
    print(file_names)
    # Select the compression mode ZIP_DEFLATED for compression
    # or zipfile.ZIP_STORED to just store the file
    compression = zipfile.ZIP_DEFLATED
    # create the zip file first parameter path/name, second mode
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            # Add file to the zip file
            # first parameter file to zip, second filename in zip
            zf.write('./' + file_name, file_name, compress_type=compression)


file_names = ["r_value_ad", "r_value_price", "choice", "cups_per_day", "init.ipynb"]
compress(file_names)
# Out:
# File Paths:
# ['r_value_ad', 'r_value_price', 'choice', 'cups_per_day', 'init.ipynb']
